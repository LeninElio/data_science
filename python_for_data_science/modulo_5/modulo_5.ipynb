# %% [markdown]
# # Numpy 1D Arrays

# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 'one', 'two'])

# %%
a[0]
# Out:
# '1'

# %%
# Visualizar el tamaño de un array
a.size
# Out:
# 7

# %%
# Verificar las dimensiones de un array
a.ndim
# Out:
# 1

# %%
type(a)
# Out:
# numpy.ndarray

# %%
c = np.array([10, 2, 3, 4, 5])

# %%
c[0] = 100
c
# Out:
# array([100,   2,   3,   4,   5])

# %%
c[1:4]
# Out:
# array([2, 3, 4])

# %%
c
# Out:
# array([100,   2,   3,   4,   5])

# %%
d = c[2:4]

# %%
d
# Out:
# array([3, 4])

# %%
u = [1, 0]
v = [0, 1]

z = []
for n, m in zip(u, v):
    z.append(n + m)

# %%
z
# Out:
# [1, 1]

# %%
u = np.array([1, 0])
v = np.array([0, 1])

# %%
# Suma de vectores
z = u + v
z
# Out:
# array([1, 1])

# %%
# resta de vectores
z = u - v
z
# Out:
# array([ 1, -1])

# %%
# Multiplicación de vectores
z = u * v
z
# Out:
# array([0, 0])

# %%
# Producto punto
np.dot(u, v)
# Out:
# 0

# %%
# Multiplicación por un escalar
y = np.array([1, 2])
z = 2 * y
z
# Out:
# array([2, 4])

# %%
# Funciones universales
a = np.array([1, -1, 1, -1])
mean_a = a.mean()
mean_a
# Out:
# 0.0

# %%
b = np.array([1, -2, 3, 4, 5])
max_b = b.max()
max_b
# Out:
# 5

# %%
# Valores de pi
np.pi
# Out:
# 3.141592653589793

# %%
# Lin-space
np.linspace(-2, 2, num=5)
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
# Graficar funciones
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# %%
x
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866,
#        0.63466518, 0.6981317 , 0.76159822, 0.82506474, 0.88853126,
#        0.95199777, 1.01546429, 1.07893081, 1.14239733, 1.20586385,
#        1.26933037, 1.33279688, 1.3962634 , 1.45972992, 1.52319644,
#        1.58666296, 1.65012947, 1.71359599, 1.77706251, 1.84052903,
#        1.90399555, 1.96746207, 2.03092858, 2.0943951 , 2.15786162,
#        2.22132814, 2.28479466, 2.34826118, 2.41172769, 2.47519421,
#        2.53866073, 2.60212725, 2.66559377, 2.72906028, 2.7925268 ,
#        2.85599332, 2.91945984, 2.98292636, 3.04639288, 3.10985939,
#        3.17332591, 3.23679243, 3.30025895, 3.36372547, 3.42719199,
#        3.4906585 , 3.55412502, 3.61759154, 3.68105806, 3.74452458,
#        3.8079911 , 3.87145761, 3.93492413, 3.99839065, 4.06185717,
#        4.12532369, 4.1887902 , 4.25225672, 4.31572324, 4.37918976,
#        4.44265628, 4.5061228 , 4.56958931, 4.63305583, 4.69652235,
#        4.75998887, 4.82345539, 4.88692191, 4.95038842, 5.01385494,
#        5.07732146, 5.14078798, 5.2042545 , 5.26772102, 5.33118753,
#        5.39465405, 5.45812057, 5.52158709, 5.58505361, 5.64852012,
#        5.71198664, 5.77545316, 5.83891968, 5.9023862 , 5.96585272,
#        6.02931923, 6.09278575, 6.15625227, 6.21971879, 6.28318531])

# %%
y
# Out:
# array([ 0.00000000e+00,  6.34239197e-02,  1.26592454e-01,  1.89251244e-01,
#         2.51147987e-01,  3.12033446e-01,  3.71662456e-01,  4.29794912e-01,
#         4.86196736e-01,  5.40640817e-01,  5.92907929e-01,  6.42787610e-01,
#         6.90079011e-01,  7.34591709e-01,  7.76146464e-01,  8.14575952e-01,
#         8.49725430e-01,  8.81453363e-01,  9.09631995e-01,  9.34147860e-01,
#         9.54902241e-01,  9.71811568e-01,  9.84807753e-01,  9.93838464e-01,
#         9.98867339e-01,  9.99874128e-01,  9.96854776e-01,  9.89821442e-01,
#         9.78802446e-01,  9.63842159e-01,  9.45000819e-01,  9.22354294e-01,
#         8.95993774e-01,  8.66025404e-01,  8.32569855e-01,  7.95761841e-01,
#         7.55749574e-01,  7.12694171e-01,  6.66769001e-01,  6.18158986e-01,
#         5.67059864e-01,  5.13677392e-01,  4.58226522e-01,  4.00930535e-01,
#         3.42020143e-01,  2.81732557e-01,  2.20310533e-01,  1.58001396e-01,
#         9.50560433e-02,  3.17279335e-02, -3.17279335e-02, -9.50560433e-02,
#        -1.58001396e-01, -2.20310533e-01, -2.81732557e-01, -3.42020143e-01,
#        -4.00930535e-01, -4.58226522e-01, -5.13677392e-01, -5.67059864e-01,
#        -6.18158986e-01, -6.66769001e-01, -7.12694171e-01, -7.55749574e-01,
#        -7.95761841e-01, -8.32569855e-01, -8.66025404e-01, -8.95993774e-01,
#        -9.22354294e-01, -9.45000819e-01, -9.63842159e-01, -9.78802446e-01,
#        -9.89821442e-01, -9.96854776e-01, -9.99874128e-01, -9.98867339e-01,
#        -9.93838464e-01, -9.84807753e-01, -9.71811568e-01, -9.54902241e-01,
#        -9.34147860e-01, -9.09631995e-01, -8.81453363e-01, -8.49725430e-01,
#        -8.14575952e-01, -7.76146464e-01, -7.34591709e-01, -6.90079011e-01,
#        -6.42787610e-01, -5.92907929e-01, -5.40640817e-01, -4.86196736e-01,
#        -4.29794912e-01, -3.71662456e-01, -3.12033446e-01, -2.51147987e-01,
#        -1.89251244e-01, -1.26592454e-01, -6.34239197e-02, -2.44929360e-16])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y)

# %% [markdown]
# # Numpy 2D Arrays

# %%
a = np.array([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
a
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %%
a.ndim
# Out:
# 2

# %%
a[0, 0]
# Out:
# 11

# %%
a[0: 2,2]
# Out:
# array([13, 23])

# %% [markdown]
# # NBA API

# %%
from nba_api.stats.static import teams
import pandas as pd

# %%
nba_teams = teams.get_teams()

# %%
nba_teams[:5]
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966}]

# %%
def one_dict(list_dict):
    keys=list_dict[0].keys()
    out_dict={key:[] for key in keys}
    for dict_ in list_dict:
        for key, value in dict_.items():
            out_dict[key].append(value)
    return out_dict

# %%
dict_nba_team=one_dict(nba_teams)
df_teams=pd.DataFrame(dict_nba_team)
df_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
df_warriors=df_teams[df_teams['nickname']=='Warriors']

# %%
df_warriors
# Out:
#            id              full_name abbreviation  nickname          city  \
# 7  1610612744  Golden State Warriors          GSW  Warriors  Golden State
#
#         state  year_founded
# 7  California          1946

# %%
id_warriors=df_warriors[['id']].values[0][0]

# %%
id_warriors
# Out:
# 1610612744

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=id_warriors)

# %%
gamefinder.get_json()
# Out:
# '{"resource": "leaguegamefinderparameters", "parameters": {"PlayerOrTeam": "T", "LeagueID": null, "Season": null, "SeasonType": null, "TeamID": "1610612744", "VsTeamID": null, "PlayerID": null, "GameID": null, "Outcome": null, "Location": null, "DateFrom": null, "DateTo": null, "VsConference": null, "VsDivision": null, "Conference": null, "Division": null, "DraftYear": null, "DraftNumber": null, "DraftRound": null, "DraftTeamID": null, "RookieYear": null, "YearsExperience": null, "SeasonSegment": null, "PORound": null, "StarterBench": null, "GtPTS": null, "GtREB": null, "GtAST": null, "GtSTL": null, "GtBLK": null, "GtOREB": null, "GtDREB": null, "GtDD": null, "GtTD": null, "GtMINUTES": null, "GtTOV": null, "GtPF": null, "GtFGM": null,
46, 0.326, 19, 30, 0.633, 18, 37, 55, 25, 4, 6, 7, 23, 20.0], ["42022", 1610612744, "GSW", "Golden State Warriors", "0042200166", "2023-04-28", "GSW vs. SAC", "L", 239, 99, 32, 86, 0.372, 10, 32, 0.313, 25, 35, 0.714, 11, 31, 42, 20, 14, 6, 18, 23, -19.0], ["42022", 1610612744, "GSW", "Golden State Warriors", "0042200165", "2023-04-26", "GSW @ SAC", "W", 240, 123, 50, 96, 0.521, 11, 38, 0.289, 12, 19, 0.632, 11, 32, 43, 33, 11, 7, 14, 24, 7.0], ["42022", 1610612744, "GSW", "Golden State Warriors", "0042200164", "2023-04-23", "GSW vs. SAC", "W", 240, 126, 45, 90, 0.5, 14, 34, 0.412, 22, 24, 0.917, 8, 36, 44, 31, 8, 6, 11, 19, 1.0], ["42022", 1610612744, "GSW", "Golden State Warriors", "0042200163", "2023-04-20", "GSW vs. SAC", "W", 241, 114, 40, 100, 0.4, 16, 50, 0.32, 18, 23, 0.783, 18, 41, 59, 31, 12, 5, 11, 19, 17.0], ["42022", 16106 ...

# %%
games = gamefinder.get_data_frames()[0]

# %%
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     42022  1610612744               GSW  Golden State Warriors  0042200236
# 1     42022  1610612744               GSW  Golden State Warriors  0042200235
# 2     42022  1610612744               GSW  Golden State Warriors  0042200234
# 3     42022  1610612744               GSW  Golden State Warriors  0042200233
# 4     42022  1610612744               GSW  Golden State Warriors  0042200232
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB   REB  AST  \
# 0  2023-05-12    GSW @ LAL  L  241  101  ...   0.714  20.0  33.0  53.0   25
# 1  2023-05-10  GSW vs. LAL  W  239  121  ...   0.933   9.0  39.0  48.0   29
# 2  2023-05-08    GSW @ LAL  L  239  101  ...   0.750   9.0  31.0  40.0   29
# 3  2023-05-06    GSW @ LAL  L  240   97  ...   0.706  14.0  28.0  42.0   26
# 4  2023-05-04  GSW vs. LAL  W  242  127  ...   0.625  13.0  42.0  55.0   38
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    3    2   10  30       -21.0
# 1    8    5   14  18        15.0
# 2    9    2   16  22        -3.0
# 3    5    6   19  22       -30.0
# 4    2    3   15  23        27.0
#
# [5 rows x 28 columns]

# %%
games_home=games[games['MATCHUP']=='GSW vs. TOR']

# %%
games_away=games[games['MATCHUP']=='GSW @ TOR']

# %%
games_home
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 46       22022  1610612744               GSW  Golden State Warriors
# 195      22021  1610612744               GSW  Golden State Warriors
# 220      22021  1610612744               GSW  Golden State Warriors
# 288      22020  1610612744               GSW  Golden State Warriors
# 303      22019  1610612744               GSW  Golden State Warriors
# 374      22019  1610612744               GSW  Golden State Warriors
# 379      42018  1610612744               GSW  Golden State Warriors
# 381      42018  1610612744               GSW  Golden State Warriors
# 382      42018  1610612744               GSW  Golden State Warriors
# 454      22018  1610612744               GSW  Golden State Warriors
# 594      22017  1610612744               GSW  Golden State Warriors
# 675      22016  1610612744               GSW  Golden State Warriors
# 1853  0020400416  2004-12-29  GSW vs. TOR  W  240  111  ...   0.857   9.0
# 1918  0020300735  2004-02-08  GSW vs. TOR  L  265   81  ...   0.621   8.0
# 2021  0020200416  2002-12-27  GSW vs. TOR  W  239  101  ...   0.939  19.0
# 2122  0020100115  2001-11-14  GSW vs. TOR  L  240   82  ...   0.667  20.0
# 2193  0020000281  2000-12-08  GSW vs. TOR  L  239   92  ...   0.630  18.0
# 2283  0029900193  1999-11-27  GSW vs. TOR  L  240   88  ...   0.706  20.0
# 2363  0029700925  1998-03-15  GSW vs. TOR  L  264   98  ...   0.583  26.0
# 2445  0029600927  1997-03-15  GSW vs. TOR  W  241  106  ...   0.708  16.0
#
#       DREB   REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 46    38.0  43.0   40    5    1   12  18        12.0
# 195   39.0  47.0   31    5    7   16  18        15.0
# 220   25.0  37.0   18   10    5   14  23         6.0
# 288   39.0  51.0   30    2   10   15  18         1.0
# 303   38.0  52.0   34    4    5   15  23        -8.0
# 374   37.0  43.0   18    8    3   20  25        10.0
# 379   31.0  42.0   28    9    6   16  23        -4.0
# 381   34.0  42.0   26    6    6   17  23       -13.0
# 382   28.0  41.0   25    8    3   14  21       -14.0
# 454   35.0  40.0   28    5   11   19  18       -20.0
# 594   31.0  37.0   32   10    7   17  15         5.0
# 675   42.0  51.0   33    4    9   20  16        10.0
# 815   25.0  34.0   31   10    6   20  29         5.0
# 833   33.0  37.0   29    8    7   17  22         8.0
# 912   31.0  45.0   35    8    8    9  18        21.0
# 1026  27.0  36.0   27   11    2   12  16         9.0
# 1092  32.0  38.0   33    3    4   14  27         7.0
# 1243  33.0  40.0   33   12    5   10  22        38.0
# 1346  24.0  42.0   22   11    1   11  16        12.0
# 1473  31.0  37.0   26    8    9   12  23         6.0
# 1537  29.0  40.0   32    7    4   12  22        11.0
# 1696  28.0  42.0   27    7    5   11  25        11.0
# 1778  35.0  45.0   37    5    4   16  20        26.0
# 1853  31.0  40.0   24    7    4   17  22         6.0
# 1918  41.0  49.0   15    5    5   18  17        -3.0
# 2021  36.0  55.0   16    5    4   19  23         5.0
# 2122  39.0  59.0   17    6   10   17  20        -7.0
# 2193  18.0  36.0   23    6    4   20  25       -16.0
# 2283  34.0  54.0   22    4    5   19  16       -18.0
# 2363  42.0  68.0   20    7    7   16  22        -2.0
# 2445  30.0  46.0   30    5    2   13  17         4.0
#
# [31 rows x 28 columns]

# %%
games_away
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 64       22022  1610612744               GSW  Golden State Warriors
# 182      22021  1610612744               GSW  Golden State Warriors
# 249      22020  1610612744               GSW  Golden State Warriors
# 380      42018  1610612744               GSW  Golden State Warriors
# 383      42018  1610612744               GSW  Golden State Warriors
# 384      42018  1610612744               GSW  Golden State Warriors
# 460      22018  1610612744               GSW  Golden State Warriors
# 555      22017  1610612744               GSW  Golden State Warriors
# 1512  1520800043  2008-07-19  GSW @ TOR  W  201   95  ...   0.781  19.0  19.0
# 1592  0020700141  2007-11-18  GSW @ TOR  W  239  106  ...   0.667  12.0  35.0
# 1679  0020600351  2006-12-17  GSW @ TOR  L  240  115  ...   0.880   8.0  30.0
# 1770  0020500322  2005-12-16  GSW @ TOR  W  240  108  ...   0.652   6.0  27.0
# 1848  0020400487  2005-01-09  GSW @ TOR  L  240   87  ...   0.917  10.0  29.0
# 1893  0020301081  2004-03-31  GSW @ TOR  W  240   85  ...   0.714  10.0  35.0
# 1998  0020200732  2003-02-14  GSW @ TOR  W  264  118  ...   0.818  16.0  37.0
# 2126  0020100064  2001-11-07  GSW @ TOR  L  240   92  ...   0.732  20.0  32.0
# 2160  0020000765  2001-02-20  GSW @ TOR  L  240  102  ...   0.600  17.0  26.0
# 2232  0029900911  2000-03-14  GSW @ TOR  L  240   78  ...   0.462  16.0  31.0
# 2424  0029700034  1997-11-04  GSW @ TOR  L  241   86  ...   0.517  23.0  35.0
# 2488  0029600277  1996-12-10  GSW @ TOR  W  239  101  ...   0.842  22.0  29.0
#
#        REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 64    41.0   31    6    2   17  21        16.0
# 182   47.0   26    5    5   20  21       -19.0
# 249   38.0   19    5    4   21  18       -53.0
# 380   37.0   27    5    7   15  22         1.0
# 383   42.0   34    7    5   15  26         5.0
# 384   38.0   29    6    2   16  27        -9.0
# 460   46.0   27    6    5   14  22        -3.0
# 555   30.0   28    4    3    6  20         2.0
# 697   35.0   33    9    7   12  25         6.0
# 714   42.0   19   15    7   21  24        -4.0
# 716   43.0   16    9    3   17  25        -6.0
# 806   43.0   22    2    5   12  24         3.0
# 887   47.0   31   11    5   12  22        24.0
# 985   41.0   25    5    5   13  22        -6.0
# 1109  49.0   22    4    8   13  19        12.0
# 1198  41.0   17    6    3   12  20        -8.0
# 1309  42.0   19   13    7   20  26         7.0
# 1335  40.0   31    7    3   13  28         1.0
# 1504  46.0   20    6    6   18  25        -4.0
# 1512  38.0   15   10    5   17  26         5.0
# 1592  47.0   20    5    3   17  22         6.0
# 1679  38.0   23    3    2   17  27        -5.0
# 1770  33.0   27   10    1   11  23        10.0
# 1848  39.0   17    5    4   16  12       -22.0
# 1893  45.0   17    8    6    9  13         7.0
# 1998  53.0   16   12    7   13  22         4.0
# 2126  52.0   19    8    5   11  18       -17.0
# 2160  43.0   30   11   10   12  17       -11.0
# 2232  47.0   20    4    9   12  25        -7.0
# 2424  58.0   26    4    3   25  24       -18.0
# 2488  51.0   15    8    4   18  18        10.0
#
# [31 rows x 28 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
games_away.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
games_home.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
ax.legend(["away", "home"])
plt.show()

# %% [markdown]
# # Translate API

# %%
from ibm_watson import SpeechToTextV1

# %%
url_s2t = "https://stream.watsonplatform.net/speech-to-text/api"
