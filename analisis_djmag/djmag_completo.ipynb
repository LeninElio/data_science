# %%
import pandas as pd

# %%
df = pd.read_csv('./data/djmag_completo.csv')
df
# Out:
#       anio  posicion                      nombre_dj movimiento variacion  \
# 0     2004         1                         Tiësto   re-entry       NaN
# 1     2004         2                   Paul van Dyk   re-entry       NaN
# 2     2004         3               Armin Van Buuren   re-entry       NaN
# 3     2004         4                          Sasha   re-entry       NaN
# 4     2004         5                  Ferry Corsten          1      Sube
# ...    ...       ...                            ...        ...       ...
# 1855  2022        96  Sunnery James & Ryan Marciano          9      Baja
# 1856  2022        97                Maya Jane Coles  new entry       NaN
# 1857  2022        98                    Jay Hardway   re-entry       NaN
# 1858  2022        99                       Cuebrick  new entry       NaN
# 1859  2022       100          The Martinez Brothers  new entry       NaN
#
#                                                   url
# 0                            /top100djs/2004/1/Tiësto
# 1                      /top100djs/2004/2/Paul-van-Dyk
# 2                  /top100djs/2004/3/Armin-Van-Buuren
# 3                             /top100djs/2004/4/Sasha
# 4                     /top100djs/2004/5/Ferry-Corsten
# ...                                               ...
# 1855  /top100djs/2022/96/Sunnery-James--Ryan-Marciano
# 1856               /top100djs/2022/97/Maya-Jane-Coles
# 1857                   /top100djs/2022/98/Jay-Hardway
# 1858                      /top100djs/2022/99/Cuebrick
# 1859        /top100djs/2022/100/The-Martinez-Brothers
#
# [1860 rows x 6 columns]

# %%
df[df['nombre_dj'] == 'Tiësto']
# Out:
#       anio  posicion nombre_dj movimiento variacion                        url
# 0     2004         1    Tiësto   re-entry       NaN   /top100djs/2004/1/Tiësto
# 65    2005         2    Tiësto          1      Baja   /top100djs/2005/2/Tiësto
# 166   2006         3    Tiësto          1      Baja   /top100djs/2006/3/Tiësto
# 265   2007         2    Tiësto          1      Sube   /top100djs/2007/2/Tiësto
# 361   2008         2    Tiësto  NON MOVER       NaN   /top100djs/2008/2/Tiësto
# 461   2009         2    Tiësto  NON MOVER       NaN   /top100djs/2009/2/Tiësto
# 562   2010         3    Tiësto          1      Baja   /top100djs/2010/3/Tiësto
# 662   2011         3    Tiësto  NON MOVER       NaN   /top100djs/2011/3/Tiësto
# 761   2012         2    Tiësto          1      Sube   /top100djs/2012/2/Tiësto
# 863   2013         4    Tiësto          2      Baja   /top100djs/2013/4/Tiësto
# 964   2014         5    Tiësto          1      Baja   /top100djs/2014/5/Tiësto
# 1064  2015         5    Tiësto  NON MOVER       NaN   /top100djs/2015/5/Tiësto
# 1164  2016         5    Tiësto  NON MOVER       NaN   /top100djs/2016/5/Tiësto
# 1264  2017         5    Tiësto  NON MOVER       NaN   /top100djs/2017/5/Tiësto
# 1365  2018         6    Tiësto          1      Baja   /top100djs/2018/6/Tiësto
# 1467  2019         8    Tiësto          2      Baja   /top100djs/2019/8/Tiësto
# 1575  2020        16    Tiësto          8      Baja  /top100djs/2020/16/Tiësto
# 1674  2021        15    Tiësto          1      Sube  /top100djs/2021/15/Tiësto
# 1774  2022        15    Tiësto  NON MOVER       NaN  /top100djs/2022/15/Tiësto

# %%
df['anio'] = df['anio'].astype(str)
df
# Out:
#       anio  posicion                      nombre_dj movimiento variacion  \
# 0     2004         1                         Tiësto   re-entry       NaN
# 1     2004         2                   Paul van Dyk   re-entry       NaN
# 2     2004         3               Armin Van Buuren   re-entry       NaN
# 3     2004         4                          Sasha   re-entry       NaN
# 4     2004         5                  Ferry Corsten          1      Sube
# ...    ...       ...                            ...        ...       ...
# 1855  2022        96  Sunnery James & Ryan Marciano          9      Baja
# 1856  2022        97                Maya Jane Coles  new entry       NaN
# 1857  2022        98                    Jay Hardway   re-entry       NaN
# 1858  2022        99                       Cuebrick  new entry       NaN
# 1859  2022       100          The Martinez Brothers  new entry       NaN
#
#                                                   url
# 0                            /top100djs/2004/1/Tiësto
# 1                      /top100djs/2004/2/Paul-van-Dyk
# 2                  /top100djs/2004/3/Armin-Van-Buuren
# 3                             /top100djs/2004/4/Sasha
# 4                     /top100djs/2004/5/Ferry-Corsten
# ...                                               ...
# 1855  /top100djs/2022/96/Sunnery-James--Ryan-Marciano
# 1856               /top100djs/2022/97/Maya-Jane-Coles
# 1857                   /top100djs/2022/98/Jay-Hardway
# 1858                      /top100djs/2022/99/Cuebrick
# 1859        /top100djs/2022/100/The-Martinez-Brothers
#
# [1860 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
nombre_dj = 'Martin Garrix'
df_tiesto = df[df['nombre_dj'] == nombre_dj]

plt.figure(figsize=(12, 6))
plt.plot(df_tiesto['anio'], df_tiesto['posicion'], marker='o', color='red', linestyle='dashed', linewidth=1, markersize=10)

for x, y in zip(df_tiesto['anio'], df_tiesto['posicion']):
    plt.annotate(str(y), (x, y), xytext=(0, 15), textcoords='offset points', ha='center', va='top')

plt.xlabel('Año de la encuesta', fontsize=12)
plt.ylabel('Posición del DJ', fontsize=12)
plt.title(f'Posición de {nombre_dj} por Año', fontsize=16)
plt.show()
