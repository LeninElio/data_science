# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/2008.csv', nrows=100000)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
# Eliminamos los valores nulos de la columna ArrDelay y DepDelay
df.dropna(inplace=True, subset=['ArrDelay', 'DepDelay'])

# %%
np.corrcoef(df['ArrDelay'], df['DepDelay'])
# Out:
# array([[1.       , 0.9422735],
#        [0.9422735, 1.       ]])

# %%
np.corrcoef([df['ArrDelay'], df['DepDelay'], df['DepTime']])
# Out:
# array([[1.        , 0.9422735 , 0.23241529],
#        [0.9422735 , 1.        , 0.25725889],
#        [0.23241529, 0.25725889, 1.        ]])

# %%
df.drop(inplace=True, columns=['Year', 'Cancelled', 'Diverted', 'UniqueCarrier'])
df.drop(inplace=True, columns=['UniqueCarrier'])
df.drop(inplace=True, columns=['TailNum'])
df.drop(inplace=True, columns=['Origin', 'Dest'])

# %%
df.corr()
# Out:
#                    Month  DayofMonth  DayOfWeek   DepTime  CRSDepTime  \
# Month                NaN         NaN        NaN       NaN         NaN
# DayofMonth           NaN    1.000000  -0.118851 -0.001168    0.003749
# DayOfWeek            NaN   -0.118851   1.000000  0.031111    0.024400
# DepTime              NaN   -0.001168   0.031111  1.000000    0.985504
# CRSDepTime           NaN    0.003749   0.024400  0.985504    1.000000
# ArrTime              NaN   -0.004445   0.021947  0.796903    0.795609
# CRSArrTime           NaN   -0.001941   0.027785  0.852191    0.862782
# FlightNum            NaN    0.072588  -0.039560  0.023409    0.023789
# ActualElapsedTime    NaN    0.004568   0.015945 -0.069542   -0.074644
# CRSElapsedTime       NaN   -0.006886   0.017744 -0.065937   -0.070060
# AirTime              NaN    0.000893   0.014324 -0.065054   -0.069232
# ArrDelay             NaN    0.027501   0.085299  0.232415    0.180684
# ...

# %%
df.drop(inplace=True, columns=['Month'])
df.drop(inplace=True, columns=['CancellationCode'])

# %%
df.corr()
# Out:
#                    DayofMonth  DayOfWeek   DepTime  CRSDepTime   ArrTime  \
# DayofMonth           1.000000  -0.118851 -0.001168    0.003749 -0.004445
# DayOfWeek           -0.118851   1.000000  0.031111    0.024400  0.021947
# DepTime             -0.001168   0.031111  1.000000    0.985504  0.796903
# CRSDepTime           0.003749   0.024400  0.985504    1.000000  0.795609
# ArrTime             -0.004445   0.021947  0.796903    0.795609  1.000000
# CRSArrTime          -0.001941   0.027785  0.852191    0.862782  0.887002
# FlightNum            0.072588  -0.039560  0.023409    0.023789  0.011193
# ActualElapsedTime    0.004568   0.015945 -0.069542   -0.074644  0.013706
# CRSElapsedTime      -0.006886   0.017744 -0.065937   -0.070060  0.016936
# AirTime              0.000893   0.014324 -0.065054   -0.069232  0.018445
# ArrDelay             0.027501   0.085299  0.232415    0.180684  0.076353
# DepDelay             0.007231   0.098220  0.257259    0.202200  0.091164
# ...

# %%
corr = round(df.corr(), 3)
corr
# Out:
#                    DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# DayofMonth              1.000     -0.119   -0.001       0.004   -0.004
# DayOfWeek              -0.119      1.000    0.031       0.024    0.022
# DepTime                -0.001      0.031    1.000       0.986    0.797
# CRSDepTime              0.004      0.024    0.986       1.000    0.796
# ArrTime                -0.004      0.022    0.797       0.796    1.000
# CRSArrTime             -0.002      0.028    0.852       0.863    0.887
# FlightNum               0.073     -0.040    0.023       0.024    0.011
# ActualElapsedTime       0.005      0.016   -0.070      -0.075    0.014
# CRSElapsedTime         -0.007      0.018   -0.066      -0.070    0.017
# AirTime                 0.001      0.014   -0.065      -0.069    0.018
# ArrDelay                0.028      0.085    0.232       0.181    0.076
# DepDelay                0.007      0.098    0.257       0.202    0.091
# ...

# %%
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_0d6a6_row0_col0, #T_0d6a6_row1_col1, #T_0d6a6_row2_col2, #T_0d6a6_row3_col3, #T_0d6a6_row4_col4, #T_0d6a6_row5_col5, #T_0d6a6_row6_col6, #T_0d6a6_row7_col7, #T_0d6a6_row8_col8, #T_0d6a6_row9_col9, #T_0d6a6_row10_col10, #T_0d6a6_row11_col11, #T_0d6a6_row12_col12, #T_0d6a6_row13_col13, #T_0d6a6_row14_col14, #T_0d6a6_row15_col15, #T_0d6a6_row16_col16, #T_0d6a6_row17_col17, #T_0d6a6_row18_col18, #T_0d6a6_row19_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...
