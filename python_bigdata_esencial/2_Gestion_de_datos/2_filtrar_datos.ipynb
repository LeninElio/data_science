# %% [markdown]
# ### El filtrado es para la obtención de información relevante en filas o columnas

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/infracciones_de_transito.csv')
df.head()
# Out:
#   DEPARTAMENTO  PROVINCIA   DISTRITO  UBIGEO  CODIGO_INFRACCION  \
# 0    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101               9254
# 1    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101               9254
# 2    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101               9250
# 3    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101               9250
# 4    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101               9253
#
#                                           INFRACCION  FECHA_INFRACCION  \
# 0  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220104
# 1  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220104
# 2  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220104
# 3  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220104
# 4  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220104
#
#    HORA_INFRACCION  MONTO_INFRACCION          LUGAR_INFRACCION  ...  \
# 0              541             230.0     JR. DOS DE MAYO C - 8  ...
# ...

# %%
df['INFRACCION'].head()
# Out:
# 0    POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...
# 1    POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...
# 2    PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...
# 3    PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...
# 4    POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...
# Name: INFRACCION, dtype: object

# %%
df['INFRACCION'].unique()
# Out:
# array(['POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPECIAL POR CIRCULAR POR EL PERÍMETRO DE LA PLAZA DE ARMAS, O POR VÍAS NO AUTORIZADAS',
#        'PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPECIAL SIN HABER OBTENIDO LA TUC O ESTE SE ENCUENTRE SUSPENDIDO, VENCIDO O CANCELADO.',
#        'PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPECIAL SIN HABER OBTENIDO LA LICENCIA DE CONDUCTOR O ESTE SE ENCUENTRE VENCIDO O CANCELADO O CUYA CATEGORÍA NO CORRESPONDE AL VEHÍCULO QUE CONDUCE',
#        'CIRCULAR O PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPECIAL SIN TENER EL SOAT O AFOCAT O ESTE NO SE ENCUENTRE VIGENTE',
#        'CIRCULAR O PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPECIAL SIN TENER EL CITV O ESTE NO SE ENCUENTRE VIGENTE',
#        'POR OBSTACULIZAR O NO PERMITIR LAS ACCIONES DE CONTROL Y/O FISCALIZACIÓN, INCUMPLIENDO CON LAS INDICACIONES DEL INSPECTOR DE TRANSPORTE O AUTORIDAD ADMINISTRATIVA; O DARSE A LA FUGA O NEGARSE A DAR IDENTIFICACIÓN.',
# ...

# %%
df['INFRACCION'].value_counts()
# Out:
# INFRACCION
# PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPECIAL SIN HABER OBTENIDO LA TUC O ESTE SE ENCUENTRE SUSPENDIDO, VENCIDO O CANCELADO.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             2626
# ...

# %%
# Slicing de filas
df[10:12]
# Out:
#    DEPARTAMENTO  PROVINCIA   DISTRITO  UBIGEO  CODIGO_INFRACCION  \
# 10    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101               9255
# 11    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101               9255
#
#                                            INFRACCION  FECHA_INFRACCION  \
# 10  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220104
# 11  CIRCULAR O PRESTAR EL SERVICIO DE TRANSPORTE P...          20220104
#
#     HORA_INFRACCION  MONTO_INFRACCION    LUGAR_INFRACCION  ...  \
# 10              803             230.0  JR. AYACUCHO C - 8  ...
# 11              803             230.0  JR. AYACUCHO C - 8  ...
#
#                       TIPO_SERVICIO TUC_ESTADO      EMPRESA  \
# 10  Transporte Especial en Mototaxi          -  SIN EMPRESA
# 11  Transporte Especial en Mototaxi          -  SIN EMPRESA
#
#    INTERNAMIENTO_VEHICULO FECHA_INTERNAMIENTO MULTA_INTERNAMIENTO  \
# 10                     SI            20220104              109.50
# ...

# %%
# Slicing de columnas
df['INFRACCION'][10:12]
# Out:
# 10    PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...
# 11    CIRCULAR O PRESTAR EL SERVICIO DE TRANSPORTE P...
# Name: INFRACCION, dtype: object

# %%
# Slicing de filas y columnas
df['INFRACCION'][10:12]
# Out:
# 10    PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...
# 11    CIRCULAR O PRESTAR EL SERVICIO DE TRANSPORTE P...
# Name: INFRACCION, dtype: object

# %%
# Filtrado por condicion
df['FECHA_INTERNAMIENTO'].value_counts()
# Out:
# FECHA_INTERNAMIENTO
# -           1388
# 20220818      88
# 20220922      77
# 20220823      75
# 20220802      72
#             ...
# 20220710       3
# 20220320       2
# 20221029       2
# 20220605       2
# 20220424       1
# Name: count, Length: 311, dtype: int64

# %%
df[df['FECHA_INTERNAMIENTO'] == '20220802'].head()
# Out:
#      DEPARTAMENTO  PROVINCIA   DISTRITO  UBIGEO  CODIGO_INFRACCION  \
# 5385    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11338
# 5386    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11338
# 5387    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5388    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5389    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
#
#                                              INFRACCION  FECHA_INFRACCION  \
# 5385  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220802
# 5386  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220802
# 5387  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220802
# 5388  CIRCULAR O PRESTAR EL SERVICIO DE TRANSPORTE P...          20220802
# 5389  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220802
#
#       HORA_INFRACCION  MONTO_INFRACCION       LUGAR_INFRACCION  ...  \
# ...

# %%
df['TIPO_SERVICIO'].unique()
# Out:
# array(['Transporte Especial en Mototaxi',
#        'Transporte de Mercancías en General',
#        'Transporte Especial de Taxi', '-',
#        'Transporte Regular de Personas',
#        'Transporte Especial de Estudiantes',
#        'Transporte Especial de Turismo',
#        'Transporte Especial en Auto Colectivo',
#        'Transporte de materiales y residuos peligrosos',
#        'Transporte Especial de Turismo de Circuito'], dtype=object)

# %%
# Múltiples condiciones
df[(df['FECHA_INTERNAMIENTO'] == '20220802') & (df['TIPO_SERVICIO'] == 'Transporte Especial en Mototaxi')]
# Out:
#      DEPARTAMENTO  PROVINCIA   DISTRITO  UBIGEO  CODIGO_INFRACCION  \
# 5385    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11338
# 5386    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11338
# 5387    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5388    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5389    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5390    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5391    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11334
# 5392    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11334
# 5393    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11347
# 5394    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11347
# 5395    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11347
# 5396    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11347
# 5397    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11347
# ...

# %%
df[df.FECHA_INTERNAMIENTO.isin(['20220802', '20220803'])].head()
# Out:
#      DEPARTAMENTO  PROVINCIA   DISTRITO  UBIGEO  CODIGO_INFRACCION  \
# 5385    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11338
# 5386    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11338
# 5387    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5388    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5389    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
#
#                                              INFRACCION  FECHA_INFRACCION  \
# 5385  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220802
# 5386  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220802
# 5387  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220802
# 5388  CIRCULAR O PRESTAR EL SERVICIO DE TRANSPORTE P...          20220802
# 5389  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220802
#
#       HORA_INFRACCION  MONTO_INFRACCION       LUGAR_INFRACCION  ...  \
# ...

# %%
df[df['FECHA_INTERNAMIENTO'].isin(['20220802', '20220803'])].head()
# Out:
#      DEPARTAMENTO  PROVINCIA   DISTRITO  UBIGEO  CODIGO_INFRACCION  \
# 5385    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11338
# 5386    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11338
# 5387    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5388    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
# 5389    CAJAMARCA  CAJAMARCA  CAJAMARCA   60101              11343
#
#                                              INFRACCION  FECHA_INFRACCION  \
# 5385  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220802
# 5386  POR PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ...          20220802
# 5387  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220802
# 5388  CIRCULAR O PRESTAR EL SERVICIO DE TRANSPORTE P...          20220802
# 5389  PRESTAR EL SERVICIO DE TRANSPORTE PÚBLICO ESPE...          20220802
#
#       HORA_INFRACCION  MONTO_INFRACCION       LUGAR_INFRACCION  ...  \
# ...

# %%
df[pd.isna(df['FECHA_INTERNAMIENTO'])].head()
# Out:
# Empty DataFrame
# Columns: [DEPARTAMENTO, PROVINCIA, DISTRITO, UBIGEO, CODIGO_INFRACCION, INFRACCION, FECHA_INFRACCION, HORA_INFRACCION, MONTO_INFRACCION, LUGAR_INFRACCION, CONDUCTOR_PRESENTE, CONDUCTOR_TENIA_LICENCIA, CONDUCTOR_CATEGORIA_LICENCIA, PLACA_VEHICULO, TIPO_TRANSPORTE, TIPO_SERVICIO, TUC_ESTADO, EMPRESA, INTERNAMIENTO_VEHICULO, FECHA_INTERNAMIENTO, MULTA_INTERNAMIENTO, SE_PAGO_MULTAS, FECHA_PAGO_MULTAS, FECHA_DESINTERNAMIENTO, FECHA_CORTE]
# Index: []
#
# [0 rows x 25 columns]

# %%
len(df[pd.notna(df['FECHA_INTERNAMIENTO'])].head())
# Out:
# 5
